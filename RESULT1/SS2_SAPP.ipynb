# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SS2_SAPP = pd.read_csv('SS2_SAPP.csv')

# %%
SS2_SAPP
# Out:
#    S/N               Student Name  Total Marks Obtained  Average (%) Grade  \
# 0    1    Ituen, Victory Emmanuel                   824         91.6     B
# 1    2  Johnbosco, Clare Chiamaka                   633         70.3     C
# 2    3   Esen, Angela Ifiok-Abasi                   612         68.0     D
# 3    4   Odoemena, Nathan Netochi                   576         64.0     E
# 4    5         Antia, David Peter                   519         64.9     E
# 5    6          Uyah, Wisdom Okon                   494         61.8     E
# 6    7       Edet, Treasure Etido                   479         59.9     F
# 7    8          Etim, Esther Etim                   473         59.1     F
# 8    9     Moses, Benedict Friday                   383         42.6   NaN
#
#   Position                   Best Subject(s)  \
# 0      1st   CRS, Civic Education, Economics
# 1      2nd  Civic Education, Data Processing
# 2      3rd    Financial Accounting, Commerce
# ...

# %%
# Create DataFrame
df = pd.DataFrame(SS2_SAPP)

# %%
b_grade_students = SS2_SAPP[SS2_SAPP['Grade'] == 'B']

# %%
b_grade_students
# Out:
#    S/N             Student Name  Total Marks Obtained  Average (%) Grade  \
# 0    1  Ituen, Victory Emmanuel                   824         91.6     B
#
#   Position                  Best Subject(s)  \
# 0      1st  CRS, Civic Education, Economics
#
#                              Strength Weakest Subject(s)  \
# 0  Strong in arts and social sciences        Mathematics
#
#                               Comments
# 0  Excellent performance, can improve.

# %%
grade_summary = SS2_SAPP['Grade'].value_counts()

# %%
grade_summary
# Out:
# Grade
# E    3
# F    2
# B    1
# C    1
# D    1
# Name: count, dtype: int64

# %%
grade_counts = SS2_SAPP['Grade'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(grade_counts, labels=grade_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Grade Distribution")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="Position", y="Average (%)", data= SS2_SAPP, marker="o")
plt.title("Average Scores by Position", fontsize=16)
plt.xlabel("Position", fontsize=12)
plt.ylabel("Average (%)", fontsize=12)
plt.grid()
plt.show()

# %%
General Performance Trends
Top Performer:

Victory Ituen (91.6%) achieved the highest average and a strong grade in most subjects, especially in arts and social sciences (CRS, Civic Education, and Economics). However, her performance in Mathematics (C5) highlights a relative weakness in analytical subjects.
Victory’s result reflects a well-rounded academic ability with some room for improvement in STEM subjects.
Middle Performers:

Students like Clare Johnbosco (70.3%) and Angela Esen (68.0%) fall into the C-D grade range, with moderate strengths in subjects like Civic Education and Financial Accounting. However, consistent weaknesses in Mathematics and English Language indicate foundational issues that hinder their overall performance.
Low Performers:

David Antia (64.9%), Wisdom Uyah (61.8%), and Esther Etim (59.1%) scored within the E-F grade range, showing weak academic performance overall. These students struggle significantly in Mathematics, English Language, and Literature, pointing to a need for targeted remedial action.
Critical Cases:

Benedict Moses (42.6%) is the lowest-performing student. His weak grades across all subjects suggest severe foundational gaps that require immediate intervention.
2. Subject-Specific Insights
Strong Subjects:

Civic Education: The most consistently high-scoring subject, with many students achieving grades between C4 and B2. This indicates strong engagement with the subject and effective teaching methods.
Financial Accounting and Commerce: Students who took these electives generally performed well, showing aptitude in business-related subjects.
Weak Subjects:

Mathematics: Almost all students struggled, with the majority earning grades between E8 and F9. This suggests conceptual difficulties and possible gaps in teaching methods.
English Language: Performance was similarly poor, with students consistently earning F9. Weak language skills likely affect their comprehension and communication across other subjects.
Economics and Literature: These subjects also show widespread underperformance, likely due to abstract concepts and low student interest.
3. Behavioral and Psychomotor Observations
Positive Traits:

Many students excel in extracurricular activities such as Sports, Drama, and Musical Skills, reflecting a balanced development beyond academics.
Attributes like Honesty, Leadership, and Obedience were generally rated high, indicating good character development.
Areas for Improvement:

Attentiveness and Participation: Several students scored C in these areas, indicating a lack of engagement during lessons, which may contribute to poor academic outcomes.
Creative Awareness and Problem-Solving Skills: While some students exhibit strong problem-solving skills, creative awareness seems underdeveloped, as reflected in lower grades in Drawing and Painting.
4. Insights on Performance Gaps
Foundational Deficiencies:

Poor performance in Mathematics and English Language suggests foundational gaps likely stemming from earlier educational stages. Without addressing these issues, improvement in other subjects may remain challenging.
STEM vs. Arts and Business:

Students generally perform better in arts and business subjects like CRS, Government, and Financial Accounting. STEM subjects, especially Mathematics, remain a significant challenge for most.
Role of Optional Subjects:

Students opting for Financial Accounting or Commerce showed stronger performance compared to core subjects, which may reflect a better alignment with their interests or learning styles.
5. Recommendations
Subject-Specific Remediation:

Focus remedial classes on Mathematics, English Language, and Economics. Emphasize foundational concepts using practical, interactive teaching methods.
Provide additional support for STEM subjects, such as after-school tutoring or peer mentoring programs.
Strengthening Language Skills:

Organize intensive English Language workshops focusing on grammar, comprehension, and writing skills to build confidence and improve overall academic performance.
Student Mentorship Programs:

Pair high-performing students like Victory Ituen with lower performers to encourage collaborative learning and knowledge sharing.
Parental Engagement:

Work with parents to ensure students have a supportive environment for learning at home, especially for struggling students.
Teacher Training:

Provide training for teachers to adopt innovative teaching approaches, especially in Mathematics and English Language.
Behavioral Improvements:

Introduce interactive activities and workshops to improve attentiveness and participation during lessons.
Monitor Progress Continuously:

Conduct frequent assessments and feedback sessions to monitor improvement and identify persistent challenges.
