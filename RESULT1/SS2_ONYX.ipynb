# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SS2_ONYX = pd.read_csv('SS2@_ONYX.csv')

# %%
SS2_ONYX
# Out:
#     S/N            Student Name  Total Marks Obtained  Average (%) Grade  \
# 0     1            Ernest, Lily                   817         90.8     B
# 1     2          Akpanika, Aldo                   758         75.8     C
# 2     3  Idawari, Joshua-Kenoye                   752         83.6     C
# 3     4         Henry, Emmanuel                   691         69.1     D
# 4     5         Thompson, Anita                   684         76.0     C
# 5     6       Cyprian, Emmanuel                   661         66.1     D
# 6     7             Etuk, David                   661         73.4     C
# 7     8          Moses, Matilda                   648         72.0     C
# 8     9   Effiong, Abasi-Ifreke                   641         64.1     E
# 9    10     Pharez, Akwawoabasi                   615         61.5     E
# 10   11            Ufot, Albert                   593         65.9     D
# 11   12        Ikediobi, Favour                   573         63.7     E
# ...

# %%
# Create DataFrame
df = pd.DataFrame(SS2_ONYX)

# %%
b_grade_students = SS2_ONYX[SS2_ONYX['Grade'] == 'B']

# %%
b_grade_students
# Out:
#    S/N  Student Name  Total Marks Obtained  Average (%) Grade Position  \
# 0    1  Ernest, Lily                   817         90.8     B      1st
#
#               Best Subject(s)                    Strength Weakest Subject(s)  \
# 0  Further Maths, Mathematics  Strong in science and math   English Language
#
#                             Comments
# 0  Excellent, very good performance.

# %%
grade_summary = SS2_ONYX['Grade'].value_counts()

# %%
grade_summary
# Out:
# Grade
# C    5
# F    5
# E    4
# D    3
# B    1
# Name: count, dtype: int64

# %%
grade_counts = SS2_ONYX['Grade'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(grade_counts, labels=grade_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Grade Distribution")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="Position", y="Average (%)", data= SS2_ONYX, marker="o")
plt.title("Average Scores by Position", fontsize=16)
plt.xlabel("Position", fontsize=12)
plt.ylabel("Average (%)", fontsize=12)
plt.grid()
plt.show()

# %%
General Performance Overview
Top Performers:

Lily Ernest (90.8%) stands out as the only student achieving above 90%, reflecting consistent excellence across subjects, particularly in science and mathematics. Her performance sets her apart as an exceptional student.
Aldo Akpanika (75.8%) and Joshua-Kenoye Idawari (83.6%) are the next best performers, with notable strengths in technical subjects like Mathematics and Further Mathematics.
Low Achievers:

Several students, including Michael Brosu (52.3%), Ikediobi Favour (50.1%), and Praise John (48.6%), performed poorly, scoring below the pass mark in most core subjects. Their grades indicate weak foundational knowledge that needs urgent attention.
Grade Distribution:

Only 1 student scored within the B range (90-94%).
The majority of students fall within C (65-74%) and D (50-64%), indicating average performance.
A significant number of students scored F (below 50%), signaling a critical need for intervention.
Subject Analysis
Strong Subjects:

Civic Education: Most students scored well, with grades ranging from C4 to B2. This indicates effective teaching strategies and student engagement in this subject.
Data Processing: Generally a high-scoring subject, with top performers achieving A1 (95-100%) and B2 (90-94%). Students appear confident with practical and theoretical aspects of this subject.
Weak Subjects:

English Language: The majority of students struggled, with many obtaining F9. Poor language proficiency may hinder their performance in other subjects, especially those requiring comprehension and communication skills.
Physics: Scores in Physics were consistently low, with many students earning E8 or F9. This suggests difficulty in understanding abstract concepts and applying formulas.
Technical Drawing: Weak grades in this subject may point to a lack of practical exposure or inadequate understanding of technical skills.
Mathematics and Further Mathematics:

Strong performers excelled, achieving A1 and B2 in Further Mathematics, but many students still struggled in general Mathematics, reflecting uneven mastery of mathematical concepts.
Psychomotor and Behavioral Observations
Positive Traits:

Many students displayed commendable social skills, including Honesty, Self-Control, and Obedience, often scoring A or B in these areas. This indicates good moral and social development.
High grades in extracurricular activities like Drama, Sports, and Musical Skills reflect balanced development beyond academics.
Areas for Improvement:

Participation and Attentiveness grades were inconsistent, with some students scoring C. This may affect their learning outcomes and requires greater teacher-student engagement.
Key Trends and Insights
Foundation Issues:

Weak performance in core subjects like English and Physics indicates foundational gaps. These gaps could be due to poor early education, inadequate teaching methods, or lack of student engagement.
Impact of Strong Performers:

High-performing students like Lily Ernest and Joshua-Kenoye Idawari set a benchmark for the class. Leveraging peer mentoring could uplift lower-performing students.
Consistency in Specific Subjects:

The consistent performance in Civic Education suggests a well-structured curriculum and effective teaching. Applying similar strategies to weaker subjects may improve outcomes.
Recommendations
Focused Remediation:

Organize extra classes or remedial sessions for subjects like English Language, Physics, and Technical Drawing to bridge learning gaps.
Employ innovative teaching strategies, such as project-based learning and practical demonstrations, especially for technical subjects.
Peer Learning:

Encourage high-performing students to mentor their peers, fostering collaborative learning and boosting class performance.
Parental Involvement:

Engage parents in supporting their children’s academics, particularly in weak subjects, through monitoring and providing learning resources.
Continuous Assessment:

Implement continuous assessments to track progress and identify struggling students early for timely intervention.
Enhancing Psychomotor Skills:

Strengthen psychomotor activities like Technical Drawing and Creative Arts by providing adequate resources and opportunities for practice.
Teacher Training:

Provide professional development for teachers to adopt modern teaching techniques and tools, particularly in challenging subjects like Physics and English.
