# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SS1_ONYX = pd.read_csv('SS1_ONYX.csv')

# %%
SS1_ONYX
# Out:
#                      Student Name Position  Average (%) Grade  \
# 0         Victor, Majesty Itohowo      1st         79.8     C
# 1       Ituen, Marvelous Emmanuel      2nd         70.4     C
# 2           Ime, Abasiekeme Itoro      3rd         68.3     D
# 3              Eze, Chisom Victor      4th         67.2     D
# 4       Adedamola, Adeniran Cyrus      5th         65.4     D
# 5             Dick, John Emmanuel      6th         64.7     E
# 6         Diepirinye, Ivan Tamuno      7th         64.0     E
# 7    Sibigem, Michael Ebubechukwu      8th         63.9     E
# 8   Aridunmu, Abdulsamad Kolawole      9th         56.1     F
# 9      Julius, Jezrahiah Temidayo     10th         56.0     F
# 10            Morrison, Jesse Ini     11th         53.3     F
# 11        Madu, David Somtochukwu     12th         50.3     F
# 12           Inyang, Praise Uduak     13th         44.5     F
#
#                                  Highest Scores  \
# ...

# %%
grade_summary = SS1_ONYX['Grade'].value_counts()

# %%
grade_summary
# Out:
# Grade
# F    5
# D    3
# E    3
# C    2
# Name: count, dtype: int64

# %%
b_grade_students = SS1_ONYX[SS1_ONYX['Grade'] == 'B']

# %%
b_grade_students
# Out:
# Empty DataFrame
# Columns: [Student Name, Position, Average (%), Grade, Highest Scores, Lowest Scores, General Remarks]
# Index: []

# %%
grade_counts = SS1_ONYX['Grade'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(grade_counts, labels=grade_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Grade Distribution")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="Position", y= "Average (%)", data= SS1_ONYX, marker="o")
plt.title("Average Scores by Position", fontsize=16)
plt.xlabel("Position", fontsize=12)
plt.ylabel("Average (%)", fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# Insights:
# Top Performer: Victor, Majesty Itohowo with an average of 79.8%.
# Lowest Performer: Inyang, Praise Uduak with an average of 44.5%.
# Common Challenges: Physics, Mathematics, and Technical Drawing are frequent low-scoring subjects.
# Recommendations: Focus on Physics, Mathematics, and English for targeted improvements. Implement remedial classes for lower-performing students.

# %% [markdown]
# Recommendations for Improving Academic Performance in SS1 Onyx Class
# 1. Subject-Specific Interventions
# Physics, Mathematics, and Technical Drawing:
# Organize remedial classes focusing on foundational concepts and problem-solving techniques.
# Provide practical demonstrations and real-life applications to enhance understanding in Physics and Technical Drawing.
# Use visual aids like diagrams and models to clarify difficult concepts.
# English Language:
# Conduct workshops on grammar, reading comprehension, and essay writing.
# Introduce group discussions and debates to improve communication skills.
# Biology and Chemistry:
# Simplify complex topics with hands-on experiments.
# Offer extra worksheets and quizzes to improve retention and application of concepts.
# 2. Individualized Attention
# Identify students consistently scoring E or F grades and assign mentors or peer tutors for one-on-one guidance.
# Conduct regular assessments to monitor progress and provide targeted feedback.
# 3. Improved Teaching Strategies
# Interactive Learning: Incorporate multimedia tools like videos, animations, and online simulations to make lessons engaging.
# Collaborative Projects: Encourage group projects and teamwork to build practical knowledge and problem-solving skills.
# Real-World Applications: Relate theoretical topics to real-world scenarios to improve interest and relevance.
# 4. Study Skills and Time Management
# Teach students how to prioritize tasks, manage time effectively, and create study schedules.
# Provide training in note-taking, summarization, and memory techniques.
# 5. Parental Involvement
# Conduct parent-teacher meetings to discuss students' challenges and jointly develop improvement plans.
# Encourage parents to supervise homework and provide a conducive learning environment at home.
# 6. Motivation and Counseling
# Motivational Talks: Invite speakers to inspire students and boost their confidence.
# Counseling Services: Address emotional or psychological barriers affecting academic performance.
# Recognize and reward incremental improvements with certificates or small awards.
# 7. Regular Performance Reviews
# Conduct weekly or bi-weekly quizzes to evaluate comprehension and address gaps promptly.
# Use detailed report cards to show progress in individual subjects.
# 8. Peer Tutoring and Group Studies
# Pair high-performing students with those who need improvement for peer tutoring sessions.
# Create small study groups to encourage collaboration and shared learning experiences.
# 9. Extracurricular Activities
# Incorporate activities like coding clubs, science fairs, and debates to promote applied knowledge and skills.
# Use these activities to create a balanced and engaging academic environment.
# 10. Resources and Materials
# Provide supplementary materials such as reference books, worksheets, and online resources for self-study.
# Encourage the use of educational apps and platforms for personalized learning.
# By implementing these strategies, SS1 Onyx students can enhance their academic performance and overall development. Regular evaluations and adjustments to these measures will ensure continued progress.

# %%
SS1_ONYX_SUB = pd.read_csv('SS1_ONYX_SUB.csv')

# %%
SS1_ONYX_SUB
# Out:
#                 Subject  A (Distinction)  B (Very Good)  C (Credit)  D (Pass)  \
# 0               Biology                0              0           1         1
# 1             Chemistry                0              0           0         1
# 2       Civic Education                0              5           3         1
# 3                Coding                0              4           1         1
# 4       Data Processing                0              2           2         1
# 5      English Language                0              0           1         0
# 6   Further Mathematics                0              0           1         1
# 7      Computer Studies                0              1           4         1
# 8           Mathematics                0              0           0         1
# 9               Physics                0              0           0         1
# 10    Technical Drawing                0              0           0         0
#
# ...
