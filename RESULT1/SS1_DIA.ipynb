# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SS1_DIA = pd.read_csv('SS1_DIA.csv')

# %%
SS1_DIA
# Out:
#                        Student Name Position  Average (%) Grade  \
# 0             Dennis Loyalty Adaeze      1st         87.0     B
# 1               Ekanem Noble Andrew      2nd         85.5     B
# 2            Akpan Iniobong Aniekan      3rd         85.3     B
# 3             Mfoniso Aniefiok Edet      4th         84.6     C
# 4            Edwin Charles Chukwuka      5th         81.3     C
# 5               Ekop Ubongabasi Uko      6th         78.8     C
# 6             Akpan Mfoniso Otobong      6th         78.8     C
# 7                Ukpai Rachel Nancy      8th         78.2     C
# 8                 Iwok Mfoniso Fred      9th         77.9     C
# 9                  John Victor Usen     10th         76.5     C
# 10        Johnbosco Mildred Mnesoma     11th         75.8     C
# 11            Effiong Toyoabasi Leo     12th         74.1     C
# 12                 James Divine Imo     12th         74.1     C
# 13            Udofia Emediong Titus     14th         73.2     C
# ...

# %% [raw]
# Key Observations:
# Top Performers:
# Civic Education has the highest number of A grades (2).
# Subjects with High Failures:
# Physics has the highest F grades (7), followed by English Language (6).
# Balanced Subjects:
# Data Processing and Coding show relatively even distributions across grades.
# Areas for Improvement:
# English Language, Physics, and Mathematics require focused interventions to reduce failures.

# %%
SS1_DIA_SUB = pd.read_csv('SS1_A_sub.csv')

# %%
SS1_DIA_SUB
# Out:
#                  Subject  A (Distinction)  B (Very Good)  C (Credit)  \
# 0   Agricultural Science                0              0           1
# 1                Biology                0              2           3
# 2              Chemistry                0              3           4
# 3        Civic Education                2              4           7
# 4                 Coding                0              3           8
# 5        Data Processing                0              2           6
# 6       English Language                0              1           3
# 7          Further Maths                0              2           5
# 8              Geography                0              2           1
# 9       Computer Studies                0              3           7
# 10           Mathematics                0              3           5
# 11               Physics                0              0           3
#
#     D (Pass)  E (Fair)  F (Fail)  Average Performance (%)
# ...

# %%
grade_summary = SS1_DIA['Grade'].value_counts()

# %%
grade_summary
# Out:
# Grade
# C    16
# D     4
# B     3
# F     2
# E     1
# Name: count, dtype: int64

# %%
b_grade_students = SS1_DIA[SS1_DIA['Grade'] == 'B']

# %%
b_grade_students
# Out:
#              Student Name Position  Average (%) Grade  \
# 0   Dennis Loyalty Adaeze      1st         87.0     B
# 1     Ekanem Noble Andrew      2nd         85.5     B
# 2  Akpan Iniobong Aniekan      3rd         85.3     B
#
#                             Highest Scores          Lowest Scores  \
# 0  Mathematics (95), Computer Studies (95)  English Language (78)
# 1          Coding (97), Further Maths (96)  English Language (74)
# 2        Civic Education (96), Coding (97)     Further Maths (73)
#
#                         General Remarks
# 0  Impressive performance. Can improve.
# 1  Impressive performance. Can improve.
# 2  Impressive performance. Can improve.

# %%
grade_counts = SS1_DIA['Grade'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(grade_counts, labels=grade_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Grade Distribution")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="Position", y= "Average (%)", data= SS1_DIA, marker="o")
plt.title("Average Scores by Position", fontsize=16)
plt.xlabel("Position", fontsize=12)
plt.ylabel("Average (%)", fontsize=12)
plt.grid()
plt.show()

# %% [raw]
# Recommendations for Improvement in Academic Performance of the SS1 Medical Class
# 1. Subject-Specific Interventions
# Physics: Organize regular tutorials focusing on core concepts and practical applications, as this subject has the highest number of failures (7 F grades).
# English Language: Conduct targeted grammar and comprehension workshops to address common challenges, especially for students struggling with sentence structure and vocabulary.
# Mathematics: Introduce step-by-step problem-solving sessions to build confidence and understanding of foundational topics. Use interactive tools to make learning engaging.
# 2. Remedial Programs
# For Low Performers: Identify students consistently scoring D, E, or F grades and arrange remedial classes during weekends or after school hours.
# Peer Tutoring: Assign high-performing students as peer mentors to provide guidance and motivation to their classmates.
# 3. Improved Teaching Strategies
# Interactive Learning: Incorporate videos, simulations, and real-world examples to enhance engagement in technical subjects like Chemistry, Physics, and Coding.
# Regular Assessments: Conduct weekly quizzes to ensure consistent evaluation and timely feedback.
# Differentiated Instruction: Adapt teaching styles to suit diverse learning needs, providing additional support to weaker students.
# 4. Encouraging Active Participation
# Motivate students to participate in classroom discussions, group projects, and co-curricular activities like debates or coding clubs to enhance practical knowledge.
# Introduce incentive systems, such as certificates or awards, for consistent academic improvement.
# 5. Parental Involvement
# Host regular parent-teacher meetings to discuss individual progress and create a collaborative improvement plan.
# Encourage parents to monitor their children’s homework and ensure a conducive learning environment at home.
# 6. Time Management and Study Skills
# Teach students how to create and follow effective study schedules.
# Provide training in note-taking, summarization, and revision techniques to improve retention and performance.
# 7. Psychological and Emotional Support
# Employ school counselors to help students manage stress, build self-confidence, and develop a positive attitude toward learning.
# Address behavioral issues, like inattentiveness and lack of self-control, identified in the psychomotor and affective performance grades.
# 8. Focus on Practical Skills
# Conduct practical sessions for science subjects to build hands-on experience.
# Introduce project-based learning in Coding and Data Processing to apply theoretical knowledge.
# 9. Regular Feedback Mechanism
# Provide timely and constructive feedback on assignments and tests.
# Use performance tracking systems to identify patterns and set achievable goals for students.
# By implementing these strategies, the academic performance of the SS1 Medical Class can be significantly improved, ensuring a balanced development across cognitive, psychomotor, and affective domains.
