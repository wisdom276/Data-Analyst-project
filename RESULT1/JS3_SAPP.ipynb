# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
JS3_SAPP = pd.read_csv('JS3_SAPP.csv')

# %%
JS3_SAPP
# Out:
#     S/N                 Student Name Position  Total Marks Obtained  \
# 0     1      Egbukole, Ivanna Chioma      1st                  1394
# 1     2           Udom, Esther Peter      2nd                  1316
# 2     3   Essang, Godswill Idongesit      3rd                  1293
# 3     4            Ekop, Akwaima Uko      4th                  1287
# 4     5     Wilson, Abasiodiong Emma      5th                  1263
# 5     6         Anlak, Light Abraham      6th                  1154
# 6     7        Ebenge, Jasmine James      7th                  1126
# 7     8  James, Marvellous Nkereuwem      8th                  1125
# 8     9       Basil, Goodness Martin      9th                  1113
# 9    10       Akpan, Precious Wisdom     10th                  1080
# 10   11          Daniel, Kufre Henry     11th                  1039
# 11   12     Anyanwu, Samuel Emmanuel     12th                   998
# 12   13   Eze, Kaosisochukwu Raymond     13th                   987
# ...

# %%
# Create DataFrame
df = pd.DataFrame(JS3_SAPP)

# %%
grade_summary = JS3_SAPP['Grade'].value_counts()

# %%
grade_summary
# Out:
# Grade
# E    8
# C    7
# F    3
# D    2
# B    1
# Name: count, dtype: int64

# %%
b_grade_students = JS3_SAPP[JS3_SAPP['Grade'] == 'B']

# %%
b_grade_students
# Out:
#    S/N             Student Name Position  Total Marks Obtained  Average (%)  \
# 0    1  Egbukole, Ivanna Chioma      1st                  1394         87.1
#
#   Grade         Performance Comment  \
# 0     B  An impressive performance.
#
#                                        Strengths  \
# 0  Strong in Home Economics and Business Studies
#
#                       Weaknesses
# 0  Needs improvement in English.

# %%
grade_counts = JS3_SAPP['Grade'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(grade_counts, labels=grade_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Grade Distribution")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="Position", y= "Average (%)", data= JS3_SAPP, marker="o")
plt.title("Average Scores by Position", fontsize=16)
plt.xlabel("Position", fontsize=12)
plt.ylabel("Average (%)", fontsize=12)
plt.grid()
plt.show()

# %%
OBSERVATION

Subject Performance Trends
Top Performing Subjects:
Business Studies:

Majority of students scored Credit (C4) or higher.
Highest score: 98% (Ivanna Chioma).
Consistent across both high and low-performing students.
Home Economics:

Strong performance among middle and top performers, with several scores above 90%.
Indicates practical skill development in students.
French:

Many students demonstrated strong understanding, with high grades like A1 and B2.
Common in top and middle performers.
Weakest Subjects:
English Language:

Multiple students scored below average (D7 or F9).
Indicative of foundational grammar and comprehension issues.
Top performer scored only 79% (Ivanna Chioma).
Basic Science:

Consistently challenging, especially for lower performers.
Lowest score: 37% (Victor Bartholomew).
Mathematics:

Struggles evident across the board, particularly for students ranked 9th–21st.
Highlights need for additional focus on numerical reasoning and foundational arithmetic.
2. Individual Student Challenges
High Performers:
Ivanna Chioma (1st):

Strengths: Exceptional in Home Economics and Business Studies.
Weakness: English Language could improve (79%).
Recommendation: Advanced enrichment classes to sustain high performance.
Esther Peter (2nd):

Strengths: Strong in Home Economics and French.
Weaknesses: Mathematics (68%) and English (68%).
Recommendation: Personalized coaching in quantitative and linguistic skills.
Middle Performers:
Light Abraham (6th):

Strengths: French (85%) and Business Studies (86%).
Weaknesses: Basic Science (53%) and Ibibio (36%).
Recommendation: Focused tutoring in science and indigenous language skills.
Jasmine James (7th):

Strengths: English (80%) and Social Studies (86%).
Weaknesses: Practical Agriculture (59%).
Recommendation: Supplementary practical sessions in Agriculture.
Low Performers:
Victor Bartholomew (15th):

Strengths: Business Studies (82%) and Basic Technology (73%).
Weaknesses: Multiple F9 grades in English, Mathematics, and Basic Science.
Recommendation: Comprehensive intervention program targeting core subjects.
Blessed Dick (21st):

Strengths: Business Studies (78%).
Weaknesses: Failing grades in key subjects (English, Mathematics, Basic Science).
Recommendation: Remedial classes and one-on-one mentoring.
3. Behavioral Strengths and Weaknesses
Strengths:
Sports and Participation:

Consistently high grades (A or B) indicate active engagement in extracurricular activities.
Suggests physical and social development.
Honesty and Obedience:

Most students scored A or B, reflecting strong moral values.
Weaknesses:
Creative Awareness:

Many students received C grades, indicating room for improvement in innovation and imagination.
Recommendation: Implement creative workshops (e.g., arts, crafts, and brainstorming sessions).
Leadership Skills:

C grades prevalent in this area, highlighting the need for programs focused on leadership and initiative.
4. General Recommendations
Curriculum Adjustment:

Place extra emphasis on English Language, Basic Science, and Mathematics.
Implement diagnostic assessments to identify root causes of subject struggles.
Enrichment Programs:

Advanced courses for top students to maintain high performance.
Practical, hands-on activities for weaker subjects (e.g., Agriculture labs, creative writing for English).
Peer Mentoring:

Pair top performers with struggling students to foster peer-led learning.
Behavioral Development:

Leadership training and creativity workshops to address weaknesses in teamwork and creative skills.
